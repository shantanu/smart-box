# %%
import pandas as pd
import numpy as np


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

import matplotlib.pyplot as plt
import tsfresh


from modAL.models import ActiveLearner
from modAL.uncertainty import uncertainty_sampling, margin_sampling, entropy_sampling

# %%
# 1) Load the old dataset
df = pd.read_csv('./2020-06-13Box0PeopleCounting.csv')
df.sort_values(by='time', inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)

df
# Out:
#       box_name    channel_name                 time     value      label
# 0         Box0         Accel X  2020-06-13 15:40:00    -0.060  1,2,3,4,5
# 17        Box0               B  2020-06-13 15:40:00   397.000  1,2,3,4,5
# 16        Box0        Pressure  2020-06-13 15:40:00  1020.746  1,2,3,4,5
# 15        Box0           Audio  2020-06-13 15:40:00     0.557  1,2,3,4,5
# 14        Box0        Magnet Z  2020-06-13 15:40:00   -77.250  1,2,3,4,5
# ...        ...             ...                  ...       ...        ...
# 48601     Box0        Pressure  2020-06-13 16:25:00  1020.597    1,2,4,5
# 48600     Box0               G  2020-06-13 16:25:00  1591.000    1,2,4,5
# 48616     Box0  Color Temp (K)  2020-06-13 16:25:00  4216.000    1,2,4,5
# 48607     Box0               B  2020-06-13 16:25:00  1183.000    1,2,4,5
# 48617     Box0     Temperature  2020-06-13 16:25:00    23.430    1,2,4,5
#
# [48618 rows x 5 columns]

# %%
df['label'].unique()
# Out:
# array(['1,2,3,4,5', '1,2,4,5', '2,3,4', '2,3,4,5', '2,3'], dtype=object)

# %%
# 2) get the segments by seeing where the labels change

start_indices = [df.iloc[0]['time']]

for i in range(1, len(df)):
    if df.iloc[i]['label'] != df.iloc[i-1]['label']:
        start_indices.append(df.iloc[i]['time'])

start_indices.append(df.iloc[-1]['time'])

start_indices
# Out:
# ['2020-06-13 15:40:00',
#  '2020-06-13 15:52:00',
#  '2020-06-13 15:56:00',
#  '2020-06-13 16:01:00',
#  '2020-06-13 16:13:00',
#  '2020-06-13 16:16:00',
#  '2020-06-13 16:17:00',
#  '2020-06-13 16:21:00',
#  '2020-06-13 16:25:00']

# %%
segments = []
for i in range(1, len(start_indices)):
    segments.append((start_indices[i-1], start_indices[i]))
    
print(segments)
# Out:
# [('2020-06-13 15:40:00', '2020-06-13 15:52:00'), ('2020-06-13 15:52:00', '2020-06-13 15:56:00'), ('2020-06-13 15:56:00', '2020-06-13 16:01:00'), ('2020-06-13 16:01:00', '2020-06-13 16:13:00'), ('2020-06-13 16:13:00', '2020-06-13 16:16:00'), ('2020-06-13 16:16:00', '2020-06-13 16:17:00'), ('2020-06-13 16:17:00', '2020-06-13 16:21:00'), ('2020-06-13 16:21:00', '2020-06-13 16:25:00')]

# %%
# 3) Relabel and normalize all labels to numerals (0, 1, 2, 3+)
for segment in segments:
    print(df.loc[df['time'] == segment[0], 'label'].iloc[0])
    numPeopleinSegment = len(str(df.loc[df['time'] == segment[0], 'label'].iloc[0]).split(","))
    print(numPeopleinSegment)
    df.loc[((segment[0] <= df['time']) & (df['time'] < segment[1])), 'label'] = numPeopleinSegment

# fix for last time stamp
df.loc[df['time'] == start_indices[-1], 'label'] = 4


df['label'].unique()
# Out:
# 1,2,3,4,5
# 5
# 1,2,4,5
# 4
# 1,2,3,4,5
# 5
# 2,3,4
# 3
# 1,2,3,4,5
# 5
# 2,3,4,5
# 4
# 2,3
# 2
# 1,2,4,5
# 4
# array([5, 4, 3, 2], dtype=int64)

# %%
df
# Out:
#       box_name    channel_name                 time     value  label
# 0         Box0         Accel X  2020-06-13 15:40:00    -0.060      5
# 17        Box0               B  2020-06-13 15:40:00   397.000      5
# 16        Box0        Pressure  2020-06-13 15:40:00  1020.746      5
# 15        Box0           Audio  2020-06-13 15:40:00     0.557      5
# 14        Box0        Magnet Z  2020-06-13 15:40:00   -77.250      5
# ...        ...             ...                  ...       ...    ...
# 48601     Box0        Pressure  2020-06-13 16:25:00  1020.597      4
# 48600     Box0               G  2020-06-13 16:25:00  1591.000      4
# 48616     Box0  Color Temp (K)  2020-06-13 16:25:00  4216.000      4
# 48607     Box0               B  2020-06-13 16:25:00  1183.000      4
# 48617     Box0     Temperature  2020-06-13 16:25:00    23.430      4
#
# [48618 rows x 5 columns]

# %%
# 4) get features for each segment

segment_features = np.empty((0, 13734), float)

for index, segment in enumerate(segments):
    if index == len(segments) - 1:
        # only last segment fix, must include the last index
        # note the change in <= from < in second line
        segment_df = df.loc[((segment[0] <= df['time']) & 
                             (df['time'] <= segment[1]))]
    else:
        segment_df = df.loc[((segment[0] <= df['time']) & 
                             (df['time'] < segment[1]))]
        
    features = tsfresh.extract_features(
                    segment_df, 
                    column_id="box_name",
                    column_sort="time", 
                    column_kind="channel_name", 
                    column_value="value")
    print(features)
    print(len(features))
    print(type(features))
    print(features.to_numpy().shape)
    segment_features = np.append(segment_features, 
                        features.to_numpy(), axis=0)
    print(segment_features)
    
print("Done computing the features: ", segment_features.shape)
# Out:
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:17<00:00,  1.96s/it]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   2.9647                              6.06
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                              -0.003101
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                               0.003086
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.001537
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                              -0.047089
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               -0.06418
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                              -0.079475
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.000195
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                              -0.025667
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               0.478117
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               0.958905
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               1.442387
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.002582
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                0.002192
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.17it/s]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   0.8797                              8.35
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                              -0.010761
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                              -0.015203
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.006724
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.040367
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                              -0.029603
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                                -0.0888
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                                0.00345
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                                  0.176
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               0.637325
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               1.285728
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               2.038136
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.000736
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                0.001165
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:08<00:00,  1.07it/s]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                  16.4503                             15.25
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                               0.446345
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                               0.419491
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                                0.02817
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.183914
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                                0.08517
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                              -0.060989
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.012706
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                               0.365238
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               0.769588
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               1.512839
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               2.228897
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.001362
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                0.001581
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:16<00:00,  1.85s/it]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                  27.4645                             22.16
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                               0.592864
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                               0.591403
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.000342
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.320586
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               0.265096
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                               0.205244
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.001496
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                               0.343417
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                              -0.289238
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               -0.56501
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                              -0.826834
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.001454
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                 0.00163
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]
#  [ 2.74645000e+01  2.21600000e+01  5.92863918e-01 ...  1.45358333e-03
#    0.00000000e+00  1.63022875e-03]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:06<00:00,  1.43it/s]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   3.0537                              7.35
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                              -0.014377
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                              -0.007964
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.012098
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.143099
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               0.121053
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                                0.10807
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.000361
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                                  0.204
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               0.428735
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               0.743485
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               1.065471
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.000131
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                 0.00049
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]
#  [ 2.74645000e+01  2.21600000e+01  5.92863918e-01 ...  1.45358333e-03
#    0.00000000e+00  1.63022875e-03]
#  [ 3.05370000e+00  7.35000000e+00 -1.43765329e-02 ...  1.31000000e-04
#    0.00000000e+00  4.90459361e-04]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:06<00:00,  1.44it/s]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   0.9402                               2.6
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                               0.009492
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                               0.002965
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.029966
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                                0.18381
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               0.131667
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                                0.08619
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.001118
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                                   0.22
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               1.131431
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               2.538693
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               4.049676
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.000148
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                0.000521
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]
#  [ 2.74645000e+01  2.21600000e+01  5.92863918e-01 ...  1.45358333e-03
#    0.00000000e+00  1.63022875e-03]
#  [ 3.05370000e+00  7.35000000e+00 -1.43765329e-02 ...  1.31000000e-04
#    0.00000000e+00  4.90459361e-04]
#  [ 9.40200000e-01  2.60000000e+00  9.49227159e-03 ...  1.48305556e-04
#    0.00000000e+00  5.20946386e-04]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.28it/s]
# Feature Extraction:   0%|                                                                        | 0/9 [00:00<?, ?it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   6.8465                              6.05
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                               0.025343
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                              -0.006043
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                                0.01226
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.294533
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               0.178027
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                               0.098733
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.005734
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                                  0.486
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                              -0.137952
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                              -0.278222
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               -0.56138
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.000462
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                0.000918
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]
#  ...
#  [ 3.05370000e+00  7.35000000e+00 -1.43765329e-02 ...  1.31000000e-04
#    0.00000000e+00  4.90459361e-04]
#  [ 9.40200000e-01  2.60000000e+00  9.49227159e-03 ...  1.48305556e-04
#    0.00000000e+00  5.20946386e-04]
#  [ 6.84650000e+00  6.05000000e+00  2.53433526e-02 ...  4.61833333e-04
#    0.00000000e+00  9.17683316e-04]]
# Feature Extraction: 100%|████████████████████████████████████████████████████████████████| 9/9 [00:07<00:00,  1.23it/s]
# variable  Accel X__abs_energy  Accel X__absolute_sum_of_changes  \
# id
# Box0                   5.8112                              4.39
#
# variable  Accel X__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# Box0                                               0.010794
#
# variable  Accel X__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# Box0                                               0.016192
#
# variable  Accel X__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# Box0                                               0.008708
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"  \
# id
# Box0                                               0.180769
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"  \
# id
# Box0                                               0.157049
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# Box0                                               0.130031
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"  \
# id
# Box0                                               0.000274
#
# variable  Accel X__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"  \
# id
# Box0                                                  0.212
#
# variable  ...  Temperature__symmetry_looking__r_0.9500000000000001  \
# id        ...
# Box0      ...                                                1.0
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_1  \
# id
# Box0                                               0.320952
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_2  \
# id
# Box0                                               0.647321
#
# variable  Temperature__time_reversal_asymmetry_statistic__lag_3  \
# id
# Box0                                               1.072507
#
# variable  Temperature__value_count__value_-1  \
# id
# Box0                                     0.0
#
# variable  Temperature__value_count__value_0  \
# id
# Box0                                    0.0
#
# variable  Temperature__value_count__value_1  Temperature__variance  \
# id
# Box0                                    0.0               0.000268
#
# variable  Temperature__variance_larger_than_standard_deviation  \
# id
# Box0                                                    0.0
#
# variable  Temperature__variation_coefficient
# id
# Box0                                  0.0007
#
# [1 rows x 13734 columns]
# 1
# <class 'pandas.core.frame.DataFrame'>
# (1, 13734)
# [[ 2.96470000e+00  6.06000000e+00 -3.10123484e-03 ...  2.58205073e-03
#    0.00000000e+00  2.19205537e-03]
#  [ 8.79700000e-01  8.35000000e+00 -1.07611157e-02 ...  7.36138889e-04
#    0.00000000e+00  1.16506672e-03]
#  [ 1.64503000e+01  1.52500000e+01  4.46345317e-01 ...  1.36205667e-03
#    0.00000000e+00  1.58076883e-03]
#  ...
#  [ 9.40200000e-01  2.60000000e+00  9.49227159e-03 ...  1.48305556e-04
#    0.00000000e+00  5.20946386e-04]
#  [ 6.84650000e+00  6.05000000e+00  2.53433526e-02 ...  4.61833333e-04
#    0.00000000e+00  9.17683316e-04]
#  [ 5.81120000e+00  4.39000000e+00  1.07935342e-02 ...  2.68256401e-04
#    0.00000000e+00  6.99923730e-04]]
# Done computing the features:  (8, 13734)

# %%
#5) train classifier on these features

labels = [5, 4, 5, 3, 5, 4, 2, 4]
X_training, y_training = np.nan_to_num(segment_features.astype('float32')), labels

rf = RandomForestClassifier(random_state=1)

#initialize learner
learner = ActiveLearner(estimator= rf,  ## nn works awful, rf is best
                    query_strategy = margin_sampling,  ## margin sampling worked best
                    X_training=X_training, y_training=y_training)

# %%
segment_features.dtype
# Out:
# dtype('float64')
